# %% [markdown]
# <a href="https://colab.research.google.com/github/RowenXu/Rowen233/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plot
fig=plot.figure(figsize=(5,5),dpi=300)
samp=plot.subplot(1,1,1)
samp.set_title('test')
fig.savefig('test.png',dpi=300)
plot.show()
